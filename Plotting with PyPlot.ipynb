# %%
using PyPlot      # if you know matplotlib in python very well

# %%
plot(randn(42))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11890c710>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x118a64290>

# %%
imshow(rand(10, 10))
set
# Out:
# set_interpolation not defined
# while loading In[15], in expression starting on line 2
#
#  in getindex at /Users/harmeling/.julia/v0.3/PyCall/src/PyCall.jl:642
#  in pysequence_query at /Users/harmeling/.julia/v0.3/PyCall/src/conversions.jl:743
#  in pytype_query at /Users/harmeling/.julia/v0.3/PyCall/src/conversions.jl:759
#  in convert at /Users/harmeling/.julia/v0.3/PyCall/src/conversions.jl:808
#  in pycall at /Users/harmeling/.julia/v0.3/PyCall/src/PyCall.jl:812
#  in fn at /Users/harmeling/.julia/v0.3/PyCall/src/conversions.jl:181
#  in close_queued_figs at /Users/harmeling/.julia/v0.3/PyPlot/src/PyPlot.jl:295
