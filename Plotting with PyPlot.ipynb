# %%
using PyPlot      # if you know matplotlib in python very well
# Out:
# INFO: Loading help data...

# %%
plot(randn(10))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10de6cb50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x10ca8ead0>
