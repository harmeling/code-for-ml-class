# %%
using Winston           # quite similar to matlab

# %%
plot(randn(20))
# Out:
# FramedPlot(...)

# %%
imagesc(randn(10,10))
# Out:
# FramedPlot(...)

# %%
plot(1:10, randn(10), 1:10, randn(10))
# Out:
# FramedPlot(...)
